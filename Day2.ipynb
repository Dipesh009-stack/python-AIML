# %%
#Elements of Python
#constants: they are used to store the value which never changes.
#pie = 3.14

# %%
#Operators: +,-, *
# Operations: Action taken over the data
#Operator: SIgn or symbol that tells which operation is to be performed.

# %%
if 5 + 10 == 15:
    print(True)
# Out:
# True

# %%
#FUndamental Data Types
#Integer, float , String

# %%
'10'+'15'
# Out:
# '1015'

# %%
5+10
# Out:
# 15

# %%
#Derived Data Type
# Is a derived data type that is made using fundamental data type
# Eg: List , Tuple, Set, String, Dictionary, Array

# %%
# VAriables:
#They are storehouse of data.
#eg: x=10, Here x is variables

# %%
# RUles of naming a variable:
# x=10, 1x=10 is invalid, x y = 10 is also invalide, there is space in between.

# %%
# print also cannot be a name of varibale, because print is a reserved word in python.

# %%
print( 'hello World')
# Out:
# hello World

# %%
print('dkmd')
# Out:
# dkmd

# %%
del print

# %%
print("dkmd")
# Out:
# dkmd

# %%
#store length, breadth, height in x,y,x and print volume v

# %%
l=10
b=20
h=20
v=l*b*h
print(f"Volume: {v}")
# Out:
# Volume: 4000

# %%
#Srtore l as 10 and b as 20, print Area:

# %%
l=10;
b=20;
a=l*b
print(f"Area is : {a}")
# Out:
# Area is : 200

# %%
# type returns the data type of variable.
type(a)
# Out:
# int

# %%
# I need to change the data type of a from int to float

# %%
a = float(a)

# %%
a
# Out:
# 200.0

# %%
# Ask user to enter his name and print hello name.
name = input("enter your name")
print(f"Hello ! {name}")
# Out:
# enter your name Dipesh
# Hello ! Dipesh

# %%
#Two number with user and print product:

a = input("Enter 1st number: ")
a = float(a)
b = input("Enter 2nd number: ")
b= float(b)
c= a*b
print(f"The product is: {c}")
# Out:
# Enter 1st number:  4
# Enter 2nd number:  20
# The product is: 80.0

# %%
# ok, if we get the input from the user, its a by default string data type. SO, keep in mind.

# %%
#Constant: Their value never changes
# PI = 3.14, this value never changes

# %%
PI = 3.14
PI = PI+2
print(PI)
# Out:
# 5.140000000000001

# %%
# So, in python theres no concept of constant but, they are written in all caps. (PI, A, B, CONST)
# and variable are written in all small.

# %%
# Operators are sign and symbol 
# Arithmetic Operator
# Logical Operator
# Relational Operator
# Comparision Operator
# Assignment Operator
# Membership Operator

# %%
#Arithmetic ( +, - *, /, // %, **)
# add 5 and 10

5+10
# Out:
# 15

# %%
# integer division
x=13
y=3
print("Integer Division Return All outcomes :  ", x/y )
print( " FLoor Division , Returns int part only: ", x//y)
print(" Modular Division, return remainder only: " , x%y)
# Out:
# Integer Division Return All outcomes :   4.333333333333333
#  FLoor Division , Returns int part only:  4
#  Modular Division, return remainder only:  1

# %%
# Exponential 
3**4
# Out:
# 81

# %%
#Assignment Operators
#equals to =
#Additional assignment +=
#Sub Assignment -=
#Division Assignment /=, //=, %=
# Exponential Assignment **=

# %%
# Assign value 10 to a variable x
x = 10

# %%
print ( " Value of 'x': ", x)
# Out:
#  Value of 'x':  10

# %%
#Additional Assignment:
#Add 7 in the value of x

x+=7 #Adds 7 to the existing value of x  which occupies less memory, Memory Management
print("The new value of x is: ",x)
# Out:
# The new value of x is:  31

# %%
#Substract value of 6
x-=6
print(x)
# Out:
# 25

# %%
#Divide the value of x by 3 

x= 22
x/=3
print(x)
# Out:
# 7.333333333333333

# %%
#Comparision Operator

# %%
x= 10
y=20
x<y
# Out:
# True

# %%
x=20
y=30
x>y
# Out:
# False

# %%
y>=30
# Out:
# True

# %%
16==y
# Out:
# False

# %%
#Logical Operators
# and, or , not
a=10
b=20
c=30
a>5 and b>5 and c>50
# Out:
# False

# %%
# OR operator
# True if one contition is true

# %%
4>5 or 5>6
# Out:
# False

# %%
not(a>b)
# Out:
# True

# %%
# Membership Operator

# %%
# in , not in  Check garxa
#Example:

abc= "Sagarmantha"
"k" in abc
'k' not in abc
# Out:
# True

# %%
'S' in abc
# Out:
# True

# %%
p=10
t=20
r=100
si = (p*t*r)/100
print(si)
# Out:
# 200.0

# %%
# Get radius of circle and print its area

PI = 3.14
r = float(input("Enter the radius of circle: "))
Area = PI*r**2
print("The area is: ", Area)
# Out:
# Enter the radius of circle:  44
# The area is:  6079.04
