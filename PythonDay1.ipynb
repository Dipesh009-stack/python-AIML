# %% [markdown]
# This is markdown heading

# %% [raw]
# python is a coding language

# %% [markdown]
# this is python class

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print ("this is the first day of my class")
# Out:
# this is the first day of my class

# %%
#python code

# %% [markdown]
# # include<Stdio.h>
# #include <conio.h>
# void main(){
# int x,y,x;
# x=10;
# y=10;
# z=x+y;
# printf("The sum is %d", &z);
# }

# %%
x=20
y=10
z=x+y
print("the sum is : ",z)
# Out:
# the sum is :  30

# %% [markdown]
# data, data type, variables and constant, simple python progrtram
# getting user input
# all those things

# %%
be careful of indent in pyhton programming language
