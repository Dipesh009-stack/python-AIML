# %%
name = "Dipesh"
age = 30
height = 5.7
is_student = True
print ("Name: ",name)
print("Data Type: ", type(name))

print(f"Name: {name}  Data Type: {type(name)}")
print(f"Age: {age} Data Type: {type(age)}")
print(f"height: {height} Data Type: {type(height)}")
print(f"Is Student: {is_student} Data Type: {type(is_student)}")
# Out:
# Name:  Dipesh
# Data Type:  <class 'str'>
# Name: Dipesh  Data Type: <class 'str'>
# Age: 30 Data Type: <class 'int'>
# height: 5.7 Data Type: <class 'float'>
# Is Student: True Data Type: <class 'bool'>

# %%
#2. Swap the values of two variables without using third Variable

# %%
a = 10
b = 20
a, b = b,a
print("A:",a)
print("B:",b)
# Out:
# A: 20
# B: 10

# %%
#Convert the string "123" to an integer and the string "45.6" to a float, then print their sum

str1 = "123"
str2 = "45.6"
strint = int(str1)
strfloat = float(str2)
sum  = strint + strfloat
print(sum)
# Out:
# 168.6

# %%
#Given the float 3.14159, round it to 2 decimal places and print the result.

num1 = 3.14159
num2 = round(num1, 2)
print(num2)
# Out:
# 3.14

# %%
#Take the string "Python" and print its length, its uppercase form, its lowercase form, and the string reversed.

# %%
str1 = "Python"
count = 0
for i in str1:
    count+=1
print("The lenght of str1 is :", count)
print("The uppercase is: " , str1.upper())
print("The lowercase is: " , str1.lower()) 
print(" The reverse of Python is: ", str1[::-1])
# Out:
# The lenght of str1 is : 6
# The uppercase is:  PYTHON
# The lowercase is:  python
#  The reverse of Python is:  nohtyP

# %%
#Store a first name and last name in separate variables. Print the full name, and also print the first letter of each name.

# %%
fname = "Dipesh"
lname = "Wosti"
print (f"The full name is : {fname} {lname} "  )
print("The first letter  of firat name is: " ,fname[:1])
print("The first letter of last name is :" , lname[:1])
# Out:
# The full name is : Dipesh Wosti
# The first letter  of firat name is:  D
# The first letter of last name is : W

# %%
#Create one example each of a list, tuple, set, and dictionary. Print a single element from each.

# %%
list1 = range(1,10)
tuple1 = range(1,10,2)
set2 = {1,2,3,4,5}
dict1 = {
    "name" : "Dipesh",
    "ID" : 234,
    "Game": "Basketball"
}

# %%
print ("The first element of list1 is " ,list1[0])
print("The first element of tuple1 is" , tuple1[0])
print("The single element of set1 is: " , set2.pop())
print("The single element of dict1 is : " , dict1["name"])
# Out:
# The first element of list1 is  1
# The first element of tuple1 is 1
# The single element of set1 is:  2
# The single element of dict1 is :  Dipesh

# %%
#Predict the data type of each value and explain why: 10, 10.0, "10", True, [10], (10,).
print("The data type of 10 is: ", type(10))
print("The data type of 10.0 is: ", type(10.0))
print("The data type of '10' is: ", type("10"))
print("The data type of True is: ", type(True))
print("The data type of [10] is: ", type([10]))
print("The data type of (10,) is: ", type((10,)))
# Out:
# The data type of 10 is:  <class 'int'>
# The data type of 10.0 is:  <class 'float'>
# The data type of '10' is:  <class 'str'>
# The data type of True is:  <class 'bool'>
# The data type of [10] is:  <class 'list'>
# The data type of (10,) is:  <class 'tuple'>

# %%
#Ask the user for their name and print a personalized greeting.

# %%
name = input("Enter your name MF ")
print(f"Your name is : {name} Welcome MF")
# Out:
# Enter your name MF  DIpesh
# Your name is : DIpesh Welcome MF

# %%
#Ask the user for two numbers, then print their sum, difference, product, and quotient.

# %%
numbers = input("Give me 2 numbers").split()
print(type(numbers))
a = int(numbers[0])
b= int(numbers[1])
print("The sum is : " ,a+b)
print("The Mul is : " ,a*b)
print("The diff is : ", a-b)
print("The quotient is : " ,a//b)
# Out:
# Give me 2 numbers 4 5
# <class 'list'>
# The sum is :  9
# The Mul is :  20
# The diff is :  -1
# The quotient is :  0

# %%
#Ask the user for the radius of a circle and compute its area and circumference.
radius = input("Give me the radius MF")
print("The area of circle is :", 3.14* int(radius)**2)
# Out:
# Give me the radius MF 4
# The area of circle is : 50.24

# %%
#Ask the user for a temperature in Celsius and convert it to Fahrenheit.

# %%
temp = input("Enter the temp MF in Celsius ok!")
print("The temp in farenheit is: ", (int(temp)*9/5)+32)
# Out:
# Enter the temp MF in Celsius ok! 43
# The temp in farenheit is:  109.4

# %%
#Ask the user for their birth year and calculate their current age.
year = input("Enter your birth year MF in AD")
print("You are :",2026-int(year))
# Out:
# Enter your birth year MF in AD 1995
# You are : 31

# %%
#Ask the user to type a sentence, then count and print the number of words in it.

sent = input(" Enter whatever you like in a sentence")
space = 0
for i in sent:
    if i == " ":
        space+=1
print("Total number of words you entered is : ", space+1)
# Out:
#  Enter whatever you like in a sentence thi is di
# Total number of words you entered is :  3

# %%
#Ask the user to enter marks for three subjects, then calculate and print the total and the percentage.

marks = input ("Enter you 3 subject marks please : ").split()
print(marks)
print("you got: ", (int(marks[0])+int(marks[1])+int(marks[2]))*0.3)
# Out:
# Enter you 3 subject marks please :  40 50 60
# ['40', '50', '60']
# you got:  45.0

# %%
#CONDITION STATEMENTS
#Take a number from the user and check whether it is positive, negative, or zero.
num = int(input("Enter a num any num MF: "))
if num>0:
    print("positive")
elif num<0:
    print("Negative")
else:
    print("ZEROOO MF !!!")
# Out:
# Enter a num any num MF:  0
# ZEROOO MF !!!

# %%
#Check whether a number entered by the user is even or odd.
if(num%2==0):
    print("ODD")
else:
    print("Even")
# Out:
# ODD

# %%
#Read three numbers and print the largest of the three.
l1, l2, l3 = input("Enter 3 numbers").split()
if l1>l2 and l2>l3:
    print("The latgest is:", l1)
elif l2>l1 and l2>l3:
    print("The latgest is:", l2)
else:
    
    print("The latgest is:", l3)
# Out:
# Enter 3 numbers 4 5 6
# The latgest is: 6

# %%
#Take a single character and check whether it is a vowel or a consonant.
cha = input("ENter a character: ")
vowel = ['a','e','i','o','u']
if cha in vowel:
    print("Its a vowel")
else:
    print("Not Vowel")
# Out:
# ENter a character:  o
# Its a vowel

# %%
#Build a simple calculator: take two numbers and an operator (+, -, *, /) and print the result.
n1 = int(input("ENter a number"))
n2 = int(input("ENter a number"))
opt = input("Enter an operator")
if opt == "+":
    print("n1+n2")
elif opt == "-":
    print("n1-n2")
elif opt == "/":
    print("n1/n2")
elif opt == "%":
    print("n1%n2")
elif opt == "*":
    print("n1*n2")
else:
    print("Invalid Operator")
